# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

path_2022 = '../data/2022/'
path = '../data/'

# %%
df_ost = pd.read_csv(path+'ost_svao_2.csv')

# %%
df_ost['date_tt'] = pd.to_datetime(df_ost['date_tt'])

# %%
df_ost = df_ost.sort_values('date_tt')

# %%
df_ost['date_tt'].max(), df_ost['date_tt'].min()
# Out:
# (Timestamp('2022-07-18 00:00:00'), Timestamp('2022-04-18 00:00:00'))

# %%
plt.figure(figsize=(20,7))
sns.countplot(df_ost['date_tt'])
plt.xticks(rotation=90)
plt.show()
# Out:
# /home/user/anaconda3/envs/env_work/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ost_14343 = df_ost.query('id_tt == 14343')

# %%
ost_14343['parent_id_group'].value_counts()
# Out:
# 10133.00    20993
# 33.00       14795
# 10127.00    13873
# 10129.00    11682
# 10123.00     9099
# 32.00        7760
# 10122.00     7106
# 10846.00     6205
# 10751.00     5516
# 10131.00     5462
# 10699.00     5380
# 10126.00     5184
# 10125.00     4656
# 10275.00     3760
# 10219.00     3700
# 10128.00     3311
# 10132.00     2896
# 10206.00     1934
# 10878.00     1832
# 10205.00     1788
# 10649.00     1752
# 10124.00     1442
# 10121.00     1296
# 10862.00     1281
# 10492.00      725
# 10245.00      624
# 10208.00      518
# 10454.00      182
# 10365.00       92
# 11.00          31
# 10938.00       17
# 10211.00       10
# 10703.00        9
# 10391.00        4
# 10701.00        2
# 10385.00        1
# 10883.00        1
# Name: parent_id_group, dtype: int64

# %%
ost_14343['post'].min(), ost_14343['post'].max()
# Out:
# (0.0, 2000.0)

# %%
ost_14343.isna().sum()
# Out:
# date_tt                  0
# id_tt                    0
# id_tov                   0
# Name_tov                 0
# parent_id_group          0
# parent_group_name        0
# id_group                 0
# group_name               0
# morning              28434
# evening                  0
# post                     0
# dtype: int64

# %%
ost_14343.query('id_tov == 22580')
# Out:
#            date_tt  id_tt  id_tov                          Name_tov  \
# 4888814 2022-04-18  14343   22580  Томаты розовые Узбекистан, 430 г
# 4786823 2022-04-19  14343   22580  Томаты розовые Узбекистан, 430 г
# 4791870 2022-04-20  14343   22580  Томаты розовые Узбекистан, 430 г
# 4796446 2022-04-21  14343   22580  Томаты розовые Узбекистан, 430 г
# 4802090 2022-04-22  14343   22580  Томаты розовые Узбекистан, 430 г
# 4815851 2022-04-25  14343   22580  Томаты розовые Узбекистан, 430 г
# 6752696 2022-04-26  14343   22580  Томаты розовые Узбекистан, 430 г
# 4827087 2022-04-27  14343   22580  Томаты розовые Узбекистан, 430 г
# 4832091 2022-04-28  14343   22580  Томаты розовые Узбекистан, 430 г
# 4840625 2022-04-30  14343   22580  Томаты розовые Узбекистан, 430 г
# 4845617 2022-05-01  14343   22580  Томаты розовые Узбекистан, 430 г
# 4851027 2022-05-02  14343   22580  Томаты розовые Узбекистан, 430 г
# 7563068 2022-05-03  14343   22580  Томаты розовые Узбекистан, 430 г
# ...

# %%
tov_22580 = df_ost[(df_ost['id_tov'] == 22580) & df_ost['date_tt'].between('2022-06-01', '2022-06-30')][['date_tt', 
      'id_tt', 'morning', 'evening', 'post']].sort_values(['id_tt', 'date_tt'])

# %%
tt = [14902, 14343, 12853, 14330, 12612, 14859, 11178, 11616, 14332, 15194, 11439, 11532]

# %%
tov_22580[tov_22580['id_tt'].isin(tt)][56:77]
# Out:
#            date_tt  id_tt  morning  evening  post
# 1373454 2022-06-01  11532     7.00     6.00  0.00
# 1377737 2022-06-02  11532     6.00     3.00  0.00
# 1381889 2022-06-03  11532     3.00     1.00  0.00
# 1386100 2022-06-04  11532     9.00     6.00  8.00
# 1390216 2022-06-05  11532     6.00     4.00  0.00
# 1394944 2022-06-06  11532     4.00     1.00  0.00
# 1404774 2022-06-08  11532     9.00     9.00  8.00
# 1409036 2022-06-09  11532     9.00     8.00  0.00
# 1413337 2022-06-10  11532     8.00     7.00  0.00
# 1418390 2022-06-11  11532     7.00     4.00  0.00
# 1426235 2022-06-13  11532     4.00     3.00  0.00
# 1429541 2022-06-14  11532     3.00     2.00  0.00
# 1436891 2022-06-16  11532     2.00     1.00  0.00
# 1442142 2022-06-17  11532     9.00     6.00  8.00
# 1446346 2022-06-18  11532     6.00     5.00  0.00
# 1450116 2022-06-19  11532     5.00     1.00  0.00
# 1458356 2022-06-21  11532     9.00     9.00  8.00
# 1467674 2022-06-23  11532     9.00     7.00  0.00
# ...
